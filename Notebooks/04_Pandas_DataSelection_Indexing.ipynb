# %% [markdown]
# # Data Indexing & Selection

# %% [markdown]
# ___Resources___
#
# https://bit.ly/2u8dj6p - pandas documentation - Indexing & Selecting Data

# %%
## Base imports

import pandas as pd
import numpy as np
pd.set_option('max_columns', 50)

# %% [markdown]
# ## Data Selection in a `Series`

# %%
# Work with our IMDB dataset again - this time using the 'title' column as the DataFrame index

movies = pd.read_csv('./Data/imdb_movies.csv', index_col='title')
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# Selecting a Series - genre
Genre = movies['genre'].copy()

type(Genre)
# Out:
# pandas.core.series.Series

# %%
# Let's take a look at the Genre series

Genre.head()
# Out:
# title
# The Shawshank Redemption     Crime
# The Godfather                Crime
# The Godfather: Part II       Crime
# The Dark Knight             Action
# Pulp Fiction                 Crime
# Name: genre, dtype: object

# %% [markdown]
# **Similar to a dictionary**, a `Series` object provides a mapping from a collection of keys to a collection of values:

# %%
Genre['12 Angry Men']
# Out:
# 'Drama'

# %% [markdown]
# Likewise `dictionary` like expressions can be used to examine keys/indices and values

# %%
'Pulp Fiction' in Genre
# Out:
# True

# %%
# Alternative method call

Genre.index.contains('Pulp Fiction')
# Out:
# True

# %%
Genre.keys()
# Out:
# Index(['The Shawshank Redemption', 'The Godfather', 'The Godfather: Part II',
#        'The Dark Knight', 'Pulp Fiction', '12 Angry Men',
#        'The Good, the Bad and the Ugly',
#        'The Lord of the Rings: The Return of the King', 'Schindler's List',
#        'Fight Club',
#        ...
#        'Law Abiding Citizen', 'Wonder Boys', 'Death at a Funeral',
#        'Blue Valentine', 'The Cider House Rules', 'Tootsie',
#        'Back to the Future Part III',
#        'Master and Commander: The Far Side of the World', 'Poltergeist',
#        'Wall Street'],
#       dtype='object', name='title', length=979)

# %%
list(Genre.items())
# Out:
# [('The Shawshank Redemption', 'Crime'),
#  ('The Godfather', 'Crime'),
#  ('The Godfather: Part II', 'Crime'),
#  ('The Dark Knight', 'Action'),
#  ('Pulp Fiction', 'Crime'),
#  ('12 Angry Men', 'Drama'),
#  ('The Good, the Bad and the Ugly', 'Western'),
#  ('The Lord of the Rings: The Return of the King', 'Adventure'),
#  ("Schindler's List", 'Biography'),
#  ('Fight Club', 'Drama'),
#  ('The Lord of the Rings: The Fellowship of the Ring', 'Adventure'),
#  ('Inception', 'Action'),
#  ('Star Wars: Episode V - The Empire Strikes Back', 'Action'),
#  ('Forrest Gump', 'Drama'),
#  ('The Lord of the Rings: The Two Towers', 'Adventure'),
#  ('Interstellar', 'Adventure'),
#  ("One Flew Over the Cuckoo's Nest", 'Drama'),
#  ('Seven Samurai', 'Drama'),
#  ('Goodfellas', 'Biography'),
#  ('Star Wars', 'Action'),
#  ('The Matrix', 'Action'),
#  ('City of God', 'Crime'),
#  ("It's a Wonderful Life", 'Drama'),
#  ('The Usual Suspects', 'Crime'),
#  ('Se7en', 'Drama'),
#  ('Life Is Beautiful', 'Comedy'),
#  ('Once Upon a Time in the West', 'Western'),
#  ('The Silence of the Lambs', 'Drama'),
#  ('Leon: The Professional', 'Crime'),
#  ('City Lights', 'Comedy'),
#  ('Spirited Away', 'Animation'),
#  ('The Intouchables', 'Biography'),
#  ('Casablanca', 'Drama'),
#  ('Whiplash', 'Drama'),
#  ('American History X', 'Crime'),
#  ('Modern Times', 'Comedy'),
#  ('Saving Private Ryan', 'Action'),
#  ('Raiders of the Lost Ark', 'Action'),
#  ('Rear Window', 'Mystery'),
#  ('Psycho', 'Horror'),
#  ('The Green Mile', 'Crime'),
#  ('Sunset Blvd.', 'Drama'),
#  ('The Pianist', 'Biography'),
#  ('The Dark Knight Rises', 'Action'),
#  ('Gladiator', 'Action'),
#  ('Terminator 2: Judgment Day', 'Action'),
#  ('Memento', 'Mystery'),
#  ('Taare Zameen Par', 'Drama'),
#  ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'Comedy'),
#  ('The Departed', 'Crime'),
#  ('Cinema Paradiso', 'Drama'),
#  ('Apocalypse Now', 'Drama'),
#  ('The Great Dictator', 'Comedy'),
#  ('The Prestige', 'Drama'),
#  ('Back to the Future', 'Adventure'),
#  ('The Lion King', 'Animation'),
#  ('The Lives of Others', 'Drama'),
#  ('Alien', 'Horror'),
#  ('Paths of Glory', 'Drama'),
#  ('Django Unchained', 'Western'),
#  ('3 Idiots', 'Comedy'),
#  ('Grave of the Fireflies', 'Animation'),
#  ('The Shining', 'Horror'),
#  ('M', 'Crime'),
#  ('WALL-E', 'Animation'),
#  ('Witness for the Prosecution', 'Crime'),
#  ('Munna Bhai M.B.B.S.', 'Comedy'),
#  ('American Beauty', 'Drama'),
#  ('Das Boot', 'Adventure'),
#  ('Princess Mononoke', 'Animation'),
#  ('Amelie', 'Comedy'),
#  ('North by Northwest', 'Adventure'),
#  ('Rang De Basanti', 'Drama'),
#  ('Jodaeiye Nader az Simin', 'Drama'),
#  ('Citizen Kane', 'Drama'),
#  ('Aliens', 'Action'),
#  ('Vertigo', 'Mystery'),
#  ('Oldeuboi', 'Drama'),
#  ('Once Upon a Time in America', 'Crime'),
#  ('Double Indemnity', 'Crime'),
#  ('Star Wars: Episode VI - Return of the Jedi', 'Action'),
#  ('Toy Story 3', 'Animation'),
#  ('Braveheart', 'Action'),
#  ('To Kill a Mockingbird', 'Drama'),
#  ('Requiem for a Dream', 'Drama'),
#  ('Lawrence of Arabia', 'Adventure'),
#  ('A Clockwork Orange', 'Crime'),
#  ('Bicycle Thieves', 'Drama'),
#  ('The Kid', 'Comedy'),
#  ('Swades', 'Drama'),
#  ('Reservoir Dogs', 'Crime'),
#  ('Eternal Sunshine of the Spotless Mind', 'Drama'),
#  ('Taxi Driver', 'Crime'),
#  ('Dilwale Dulhania Le Jayenge', 'Comedy'),
#  ("Singin' in the Rain", 'Comedy'),
#  ('All About Eve', 'Drama'),
#  ('Yojimbo', 'Action'),
#  ('The Sting', 'Comedy'),
#  ('Rashomon', 'Crime'),
#  ('Amadeus', 'Biography'),
#  ('The Treasure of the Sierra Madre', 'Action'),
#  ('Monty Python and the Holy Grail', 'Adventure'),
#  ('Full Metal Jacket', 'Drama'),
#  ('The Apartment', 'Comedy'),
#  ('Ikiru', 'Drama'),
#  ('The Third Man', 'Film-Noir'),
#  ('Snatch.', 'Comedy'),
#  ('For a Few Dollars More', 'Western'),
#  ('Metropolis', 'Drama'),
#  ('Dil Chahta Hai', 'Comedy'),
#  ('2001: A Space Odyssey', 'Mystery'),
#  ('Some Like It Hot', 'Comedy'),
#  ('L.A. Confidential', 'Crime'),
#  ('Batman Begins', 'Action'),
#  ('Inglourious Basterds', 'Adventure'),
#  ('Scarface', 'Crime'),
#  ('Mr. Smith Goes to Washington', 'Drama'),
#  ('Toy Story', 'Animation'),
#  ('Indiana Jones and the Last Crusade', 'Action'),
#  ('Unforgiven', 'Western'),
#  ('The Great Escape', 'Adventure'),
#  ('Jagten', 'Drama'),
#  ('On the Waterfront', 'Crime'),
#  ('The General', 'Action'),
#  ('Raging Bull', 'Biography'),
#  ('Downfall', 'Biography'),
#  ('Up', 'Animation'),
#  ('Wild Strawberries', 'Drama'),
#  ('The Gold Rush', 'Adventure'),
#  ('Ran', 'Action'),
#  ('Chinatown', 'Drama'),
#  ('My Neighbor Totoro', 'Animation'),
#  ('Judgment at Nuremberg', 'Drama'),
#  ('Barfi!', 'Adventure'),
#  ('The Seventh Seal', 'Drama'),
#  ('Heat', 'Action'),
#  ("Pan's Labyrinth", 'Drama'),
#  ('The Bridge on the River Kwai', 'Adventure'),
#  ('Die Hard', 'Action'),
#  ('Good Will Hunting', 'Drama'),
#  ('The Wages of Fear', 'Adventure'),
#  ('The Secret in Their Eyes', 'Drama'),
#  ('Lagaan: Once Upon a Time in India', 'Adventure'),
#  ('The Wolf of Wall Street', 'Biography'),
#  ('It Happened One Night', 'Comedy'),
#  ('Blade Runner', 'Sci-Fi'),
#  ('Warrior', 'Drama'),
#  ("Howl's Moving Castle", 'Animation'),
#  ('The Elephant Man', 'Biography'),
#  ('Rebecca', 'Mystery'),
#  ('Incendies', 'Drama'),
#  ('Lock, Stock and Two Smoking Barrels', 'Comedy'),
#  ('V for Vendetta', 'Action'),
#  ('The Big Lebowski', 'Comedy'),
#  ('Cool Hand Luke', 'Crime'),
#  ('Relatos salvajes', 'Comedy'),
#  ('Casino', 'Biography'),
#  ('Gone with the Wind', 'Drama'),
#  ('Gone Girl', 'Drama'),
#  ('The Best Years of Our Lives', 'Drama'),
#  ('How to Train Your Dragon', 'Animation'),
#  ('Diabolique', 'Horror'),
#  ('Gran Torino', 'Drama'),
#  ('Rush', 'Action'),
#  ('Into the Wild', 'Adventure'),
#  ('My Sassy Girl', 'Comedy'),
#  ('The Deer Hunter', 'Drama'),
#  ('Mary and Max', 'Animation'),
#  ("Hachi: A Dog's Tale", 'Drama'),
#  ('The Maltese Falcon', 'Crime'),
#  ('A Beautiful Mind', 'Biography'),
#  ('Dial M for Murder', 'Crime'),
#  ('Trainspotting', 'Drama'),
#  ('Tae Guk Gi: The Brotherhood of War', 'Action'),
#  ('Persona', 'Drama'),
#  ('Touch of Evil', 'Crime'),
#  ('Fargo', 'Crime'),
#  ('The Avengers', 'Action'),
#  ('The 400 Blows', 'Crime'),
#  ('The Princess Bride', 'Adventure'),
#  ('Hotel Rwanda', 'Drama'),
#  ('Stalker', 'Drama'),
#  ('The Battle of Algiers', 'Crime'),
#  ('Underground', 'Comedy'),
#  ('Fanny and Alexander', 'Drama'),
#  ('Network', 'Drama'),
#  ('The Thing', 'Horror'),
#  ('Butch Cassidy and the Sundance Kid', 'Biography'),
#  ('The Grapes of Wrath', 'Drama'),
#  ('Black Cat, White Cat', 'Comedy'),
#  ('Life of Brian', 'Comedy'),
#  ('The Sixth Sense', 'Drama'),
#  ('Finding Nemo', 'Animation'),
#  ('Nausicaa of the Valley of the Wind', 'Animation'),
#  ('Kingsman: The Secret Service', 'Action'),
#  ('Platoon', 'Drama'),
#  ('Guardians of the Galaxy', 'Action'),
#  ('In the Name of the Father', 'Biography'),
#  ('Kill Bill: Vol. 1', 'Action'),
#  ('No Country for Old Men', 'Crime'),
#  ('Le Samourai', 'Crime'),
#  ('12 Years a Slave', 'Biography'),
#  ("La leggenda del pianista sull'oceano", 'Drama'),
#  ('8 1/2', 'Drama'),
#  ('Ben-Hur', 'Adventure'),
#  ('Amores Perros', 'Drama'),
#  ('Stand by Me', 'Adventure'),
#  ('What Ever Happened to Baby Jane?', 'Drama'),
#  ('Annie Hall', 'Comedy'),
#  ('The Imitation Game', 'Biography'),
#  ('Laura', 'Film-Noir'),
#  ('Departures', 'Drama'),
#  ('Infernal Affairs', 'Crime'),
#  ('There Will Be Blood', 'Drama'),
#  ('The Grand Budapest Hotel', 'Adventure'),
#  ('La Strada', 'Drama'),
#  ('Sin City', 'Crime'),
#  ('Memories of Murder', 'Crime'),
#  ('Donnie Darko', 'Drama'),
#  ("Who's Afraid of Virginia Woolf?", 'Drama'),
#  ('Gandhi', 'Biography'),
#  ('Solaris', 'Drama'),
#  ('Harry Potter and the Deathly Hallows: Part 2', 'Adventure'),
#  ('Paris, Texas', 'Drama'),
#  ('The Wizard of Oz', 'Adventure'),
#  ('3-Iron', 'Crime'),
#  ('Boyhood', 'Drama'),
#  ('Million Dollar Baby', 'Drama'),
#  ('The Last Picture Show', 'Drama'),
#  ('Strangers on a Train', 'Crime'),
#  ('Cat on a Hot Tin Roof', 'Drama'),
#  ('La Dolce Vita', 'Comedy'),
#  ('Chungking Express', 'Drama'),
#  ('The Night of the Hunter', 'Crime'),
#  ('La Haine', 'Crime'),
#  ('Yip Man', 'Action'),
#  ('High Noon', 'Western'),
#  ('Notorious', 'Drama'),
#  ('Before Sunrise', 'Drama'),
#  ('Elite Squad: The Enemy Within', 'Action'),
#  ('The Bourne Ultimatum', 'Action'),
#  ('Castle in the Sky', 'Animation'),
#  ('The Celebration', 'Drama'),
#  ('Spring, Summer, Fall, Winter... and Spring', 'Drama'),
#  ('Shutter Island', 'Mystery'),
#  ('Barry Lyndon', 'Adventure'),
#  ('Stalag 17', 'Comedy'),
#  ('Three Colors: Red', 'Drama'),
#  ('X-Men: Days of Future Past', 'Action'),
#  ('Sleuth', 'Mystery'),
#  ('In the Mood for Love', 'Drama'),
#  ('The Man Who Shot Liberty Valance', 'Drama'),
#  ('Arsenic and Old Lace', 'Comedy'),
#  ('The Big Sleep', 'Crime'),
#  ('Roman Holiday', 'Comedy'),
#  ('The Philadelphia Story', 'Comedy'),
#  ('Akira', 'Animation'),
#  ('Anatomy of a Murder', 'Crime'),
#  ('The Cabinet of Dr. Caligari', 'Crime'),
#  ('The Help', 'Drama'),
#  ('The Sea Inside', 'Biography'),
#  ('Elite Squad', 'Action'),
#  ('The Hustler', 'Drama'),
#  ('Rio Bravo', 'Western'),
#  ('Twelve Monkeys', 'Mystery'),
#  ('Harvey', 'Comedy'),
#  ('A Christmas Story', 'Comedy'),
#  ('Jaws', 'Drama'),
#  ('The Raid 2', 'Action'),
#  ('Rocky', 'Drama'),
#  ('Wings of Desire', 'Drama'),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 'Adventure'),
#  ('The Killing', 'Crime'),
#  ('Papillon', 'Biography'),
#  ("The King's Speech", 'Biography'),
#  ('Groundhog Day', 'Comedy'),
#  ('A Fistful of Dollars', 'Action'),
#  ('Monsters, Inc.', 'Animation'),
#  ('Dog Day Afternoon', 'Crime'),
#  ('The Perks of Being a Wallflower', 'Drama'),
#  ('Young Frankenstein', 'Comedy'),
#  ('The Terminator', 'Action'),
#  ('Harold and Maude', 'Comedy'),
#  ('Before Sunset', 'Drama'),
#  ('A Streetcar Named Desire', 'Drama'),
#  ('Bringing Up Baby', 'Comedy'),
#  ('The Diving Bell and the Butterfly', 'Biography'),
#  ('His Girl Friday', 'Comedy'),
#  ('Sling Blade', 'Drama'),
#  ('All Quiet on the Western Front', 'Drama'),
#  ('Prisoners', 'Crime'),
#  ('The Return', 'Drama'),
#  ('The Manchurian Candidate', 'Mystery'),
#  ('Duck Soup', 'Comedy'),
#  ('Beauty and the Beast', 'Animation'),
#  ('The Truman Show', 'Drama'),
#  ('The Wild Bunch', 'Action'),
#  ('Rope', 'Crime'),
#  ('The Graduate', 'Comedy'),
#  ('Jurassic Park', 'Adventure'),
#  ('Dogville', 'Crime'),
#  ('Furious 7', 'Action'),
#  ('Patton', 'Biography'),
#  ('The Nightmare Before Christmas', 'Animation'),
#  ('Being There', 'Comedy'),
#  ('Persepolis', 'Animation'),
#  ('This Is Spinal Tap', 'Comedy'),
#  ('East of Eden', 'Drama'),
#  ('Pink Floyd The Wall', 'Animation'),
#  ('Blood Diamond', 'Adventure'),
#  ('Big Fish', 'Adventure'),
#  ('Slumdog Millionaire', 'Drama'),
#  ('Star Trek', 'Action'),
#  ('The Straight Story', 'Biography'),
#  ('Crimes and Misdemeanors', 'Comedy'),
#  ('Charade', 'Comedy'),
#  ('JFK', 'Drama'),
#  ('Dawn of the Dead', 'Horror'),
#  ('Magnolia', 'Drama'),
#  ('Manhattan', 'Comedy'),
#  ('Central Station', 'Drama'),
#  ('Brazil', 'Sci-Fi'),
#  ('The Exorcist', 'Horror'),
#  ('Her', 'Drama'),
#  ('Dancer in the Dark', 'Crime'),
#  ('Rain Man', 'Drama'),
#  ('Talk to Her', 'Drama'),
#  ('The Adventures of Robin Hood', 'Action'),
#  ('Aguirre, the Wrath of God', 'Adventure'),
#  ('In the Heat of the Night', 'Crime'),
#  ('Nosferatu', 'Horror'),
#  ('Black Swan', 'Drama'),
#  ('Ratatouille', 'Animation'),
#  ('The Searchers', 'Adventure'),
#  ('Short Term 12', 'Drama'),
#  ('Doctor Zhivago', 'Drama'),
#  ('Life of Pi', 'Adventure'),
#  ("All the President's Men", 'Drama'),
#  ('Battleship Potemkin', 'History'),
#  ('Dances with Wolves', 'Adventure'),
#  ('Catch Me If You Can', 'Biography'),
#  ('Cinderella Man', 'Biography'),
#  ('Dead Poets Society', 'Drama'),
#  ('Ghost in the Shell', 'Animation'),
#  ('Head-On', 'Drama'),
#  ("No Man's Land", 'Drama'),
#  ('Dallas Buyers Club', 'Biography'),
#  ('Days of Heaven', 'Drama'),
#  ('The Sound of Music', 'Biography'),
#  ('District 9', 'Action'),
#  ('Shadow of a Doubt', 'Thriller'),
#  ('Frankenstein', 'Horror'),
#  ('Shaun of the Dead', 'Comedy'),
#  ('Night of the Living Dead', 'Horror'),
#  ('Kill Bill: Vol. 2', 'Action'),
#  ('Secrets & Lies', 'Drama'),
#  ('The Artist', 'Comedy'),
#  ('Aladdin', 'Animation'),
#  ('The Lady Vanishes', 'Comedy'),
#  ('The Hobbit: The Desolation of Smaug', 'Adventure'),
#  ('Let the Right One In', 'Drama'),
#  ('Fiddler on the Roof', 'Drama'),
#  ('The Hobbit: An Unexpected Journey', 'Adventure'),
#  ('Three Colors: Blue', 'Drama'),
#  ("Rosemary's Baby", 'Drama'),
#  ('Mystic River', 'Crime'),
#  ('Serenity', 'Action'),
#  ('Amarcord', 'Comedy'),
#  ('Planet of the Apes', 'Adventure'),
#  ('True Romance', 'Crime'),
#  ('Hannah and Her Sisters', 'Comedy'),
#  ('Moon', 'Drama'),
#  ('Before Midnight', 'Drama'),
#  ('My Name Is Khan', 'Drama'),
#  ('Scent of a Woman', 'Drama'),
#  ('Mulholland Dr.', 'Drama'),
#  ('King Kong', 'Adventure'),
#  ('The Fault in Our Stars', 'Drama'),
#  ('The Incredibles', 'Animation'),
#  ('Edward Scissorhands', 'Drama'),
#  ('Casino Royale', 'Action'),
#  ('How to Train Your Dragon 2', 'Animation'),
#  ('In Bruges', 'Comedy'),
#  ('The Untouchables', 'Crime'),
#  ('Breathless', 'Crime'),
#  ('Spartacus', 'Action'),
#  ('The Iron Giant', 'Animation'),
#  ('Midnight Cowboy', 'Drama'),
#  ('The Blues Brothers', 'Action'),
#  ('Freaks', 'Drama'),
#  ('Letters from Iwo Jima', 'Drama'),
#  ('Edge of Tomorrow', 'Action'),
#  ('Glory', 'Drama'),
#  ('The African Queen', 'Adventure'),
#  ('Birdman: Or (The Unexpected Virtue of Ignorance)', 'Comedy'),
#  ('Big Hero 6', 'Animation'),
#  ('Almost Famous', 'Drama'),
#  ('The Notebook', 'Drama'),
#  ('The Conversation', 'Drama'),
#  ('The Breakfast Club', 'Comedy'),
#  ('The Pursuit of Happyness', 'Biography'),
#  ('The Killer', 'Action'),
#  ('Once', 'Drama'),
#  ('Ying xiong', 'Action'),
#  ('The Remains of the Day', 'Drama'),
#  ('The Bride of Frankenstein', 'Horror'),
#  ('The Wrestler', 'Drama'),
#  ('Nightcrawler', 'Crime'),
#  ('Gravity', 'Sci-Fi'),
#  ('Hard Boiled', 'Action'),
#  ('Bonnie and Clyde', 'Biography'),
#  ('The Bourne Identity', 'Action'),
#  ('Key Largo', 'Crime'),
#  ('Nine Queens', 'Crime'),
#  ('Toy Story 2', 'Animation'),
#  ('The Killing Fields', 'Drama'),
#  ('All About My Mother', 'Drama'),
#  ('Cowboy Bebop: The Movie', 'Animation'),
#  ('Ed Wood', 'Biography'),
#  ('Stagecoach', 'Adventure'),
#  ('The Man Who Would Be King', 'Action'),
#  ('The Outlaw Josey Wales', 'Western'),
#  ('Children of Men', 'Drama'),
#  ('The Insider', 'Biography'),
#  ('The Right Stuff', 'Adventure'),
#  ('Badlands', 'Crime'),
#  ('A Prophet', 'Crime'),
#  ('4 Months, 3 Weeks and 2 Days', 'Drama'),
#  ('Le passe', 'Drama'),
#  ('The Fall', 'Adventure'),
#  ('Breaking the Waves', 'Drama'),
#  ('Mr. Nobody', 'Drama'),
#  ('Crash', 'Drama'),
#  ('Avatar', 'Action'),
#  ('Iron Man', 'Action'),
#  ('Do the Right Thing', 'Comedy'),
#  ("Carlito's Way", 'Crime'),
#  ('Crouching Tiger, Hidden Dragon', 'Action'),
#  ('Lilya 4-Ever', 'Crime'),
#  ('The Chorus', 'Drama'),
#  ('The Boondock Saints', 'Action'),
#  ("Miller's Crossing", 'Crime'),
#  ('Walk the Line', 'Biography'),
#  ('Shrek', 'Animation'),
#  ('My Fair Lady', 'Drama'),
#  ('The Ten Commandments', 'Adventure'),
#  ('The Fighter', 'Biography'),
#  ('Captain Phillips', 'Biography'),
#  ('Cabaret', 'Drama'),
#  ('Halloween', 'Drama'),
#  ('My Left Foot', 'Biography'),
#  ('Miracle on 34th Street', 'Comedy'),
#  ('The Man from Nowhere', 'Action'),
#  ('Toki o kakeru shojo', 'Animation'),
#  ('Little Miss Sunshine', 'Adventure'),
#  ('Taken', 'Action'),
#  ('Blue Is the Warmest Color', 'Drama'),
#  ('Boogie Nights', 'Drama'),
#  ('Hot Fuzz', 'Comedy'),
#  ("Ferris Bueller's Day Off", 'Comedy'),
#  ("The World's Fastest Indian", 'Biography'),
#  ("Kiki's Delivery Service", 'Animation'),
#  ('Down by Law', 'Comedy'),
#  ('Glengarry Glen Ross', 'Drama'),
#  ('Clerks', 'Comedy'),
#  ("Adam's Apples", 'Comedy'),
#  ('The Girl with the Dragon Tattoo', 'Crime'),
#  ('The 39 Steps', 'Mystery'),
#  ('E.T. the Extra-Terrestrial', 'Family'),
#  ('Tombstone', 'Action'),
#  ('Predator', 'Action'),
#  ('Tangled', 'Animation'),
#  ("Guess Who's Coming to Dinner", 'Comedy'),
#  ('Ordinary People', 'Drama'),
#  ('The Best Offer', 'Crime'),
#  ('Silver Linings Playbook', 'Comedy'),
#  ('Hamlet', 'Drama'),
#  ('Amour', 'Drama'),
#  ('I Saw the Devil', 'Crime'),
#  ('The Motorcycle Diaries', 'Adventure'),
#  ('Office Space', 'Comedy'),
#  ('Evil', 'Drama'),
#  ('The Girl with the Dragon Tattoo', 'Crime'),
#  ('Withnail & I', 'Comedy'),
#  ('The Day the Earth Stood Still', 'Sci-Fi'),
#  ('Black Book', 'Drama'),
#  ('Evil Dead II', 'Comedy'),
#  ('Kaze tachinu', 'Animation'),
#  ('Star Trek Into Darkness', 'Action'),
#  ('The Triplets of Belleville', 'Animation'),
#  ('Open Your Eyes', 'Drama'),
#  ('The Magnificent Seven', 'Action'),
#  ('Drive', 'Crime'),
#  ('Mississippi Burning', 'Crime'),
#  ('The Lego Movie', 'Animation'),
#  ('The Day of the Jackal', 'Crime'),
#  ('Misery', 'Thriller'),
#  ('Willy Wonka & the Chocolate Factory', 'Family'),
#  ('Fantasia', 'Animation'),
#  ('Gattaca', 'Drama'),
#  ('American Gangster', 'Biography'),
#  ('Porco Rosso', 'Animation'),
#  ('The French Connection', 'Action'),
#  ('The Boy in the Striped Pajamas', 'Drama'),
#  ('Empire of the Sun', 'Drama'),
#  ('About Time', 'Drama'),
#  ('Blue Velvet', 'Crime'),
#  ('In America', 'Drama'),
#  ('The Curious Case of Benjamin Button', 'Drama'),
#  ('The Last of the Mohicans', 'Action'),
#  ('Moonrise Kingdom', 'Adventure'),
#  ('Rebel Without a Cause', 'Drama'),
#  ('Fantastic Mr. Fox', 'Animation'),
#  ('Invasion of the Body Snatchers', 'Horror'),
#  ('October Sky', 'Biography'),
#  ('Dirty Harry', 'Action'),
#  ('Ghostbusters', 'Comedy'),
#  ('Captain America: The Winter Soldier', 'Action'),
#  ('Wreck-It Ralph', 'Animation'),
#  ('The Hangover', 'Comedy'),
#  ('Back to the Future Part II', 'Adventure'),
#  ('Belle de Jour', 'Drama'),
#  ('O Brother, Where Art Thou?', 'Adventure'),
#  ('Repulsion', 'Drama'),
#  ('Airplane!', 'Comedy'),
#  ('Pride & Prejudice', 'Drama'),
#  ('Zulu', 'Drama'),
#  ('Night on Earth', 'Comedy'),
#  ('From Here to Eternity', 'Drama'),
#  ('Apocalypto', 'Action'),
#  ('Atonement', 'Drama'),
#  ('The Dirty Dozen', 'Action'),
#  ('X-Men: First Class', 'Action'),
#  ('Run Lola Run', 'Action'),
#  ('The Longest Day', 'Action'),
#  ('Zelig', 'Comedy'),
#  ('The Last Emperor', 'Biography'),
#  ('The Goonies', 'Adventure'),
#  ('The White Ribbon', 'Drama'),
#  ('The Fugitive', 'Action'),
#  ('The Color Purple', 'Drama'),
#  ('South Park: Bigger Longer & Uncut', 'Animation'),
#  ('(500) Days of Summer', 'Comedy'),
#  ('Lost in Translation', 'Drama'),
#  ('Argo', 'Drama'),
#  ('Blazing Saddles', 'Comedy'),
#  ("Breakfast at Tiffany's", 'Comedy'),
#  ('Finding Neverland', 'Biography'),
#  ('The Experiment', 'Drama'),
#  ('Lucky Number Slevin', 'Crime'),
#  ('The Theory of Everything', 'Biography'),
#  ('Harry Potter and the Prisoner of Azkaban', 'Adventure'),
#  ('Kung Fu Hustle', 'Action'),
#  ('Being John Malkovich', 'Comedy'),
#  ('The Social Network', 'Biography'),
#  ('3:10 to Yuma', 'Adventure'),
#  ('The Name of the Rose', 'Crime'),
#  ('Mary Poppins', 'Comedy'),
#  ('The Game', 'Drama'),
#  ('Changeling', 'Drama'),
#  ('Donnie Brasco', 'Biography'),
#  ('Serpico', 'Biography'),
#  ("What's Eating Gilbert Grape", 'Drama'),
#  ('Goldfinger', 'Action'),
#  ('Nebraska', 'Adventure'),
#  ('The Sandlot', 'Comedy'),
#  ('Boyz n the Hood', 'Crime'),
#  ('The Bourne Supremacy', 'Action'),
#  ('Skyfall', 'Action'),
#  ('Ray', 'Biography'),
#  ('300', 'Action'),
#  ('A Bronx Tale', 'Crime'),
#  ('The Birds', 'Horror'),
#  ('Battle Royale', 'Action'),
#  ('Control', 'Biography'),
#  ('Kramer vs. Kramer', 'Drama'),
#  ('Deliverance', 'Adventure'),
#  ("Ocean's Eleven", 'Crime'),
#  ('As Good as It Gets', 'Comedy'),
#  ('Awakenings', 'Biography'),
#  ('The King of Comedy', 'Comedy'),
#  ('Man on Fire', 'Action'),
#  ('Sabrina', 'Comedy'),
#  ('Dark City', 'Mystery'),
#  ('Good Bye Lenin!', 'Comedy'),
#  ('Remember the Titans', 'Biography'),
#  ('Star Trek II: The Wrath of Khan', 'Action'),
#  ('Road to Perdition', 'Crime'),
#  ('Rushmore', 'Comedy'),
#  ('The Machinist', 'Drama'),
#  ('Flipped', 'Comedy'),
#  ('The Count of Monte Cristo', 'Action'),
#  ('Detachment', 'Drama'),
#  ('Love Me If You Dare', 'Comedy'),
#  ('Dead Man', 'Drama'),
#  ('The Purple Rose of Cairo', 'Comedy'),
#  ('21 Grams', 'Crime'),
#  ('50/50', 'Comedy'),
#  ('Kick-Ass', 'Action'),
#  ('Delicatessen', 'Comedy'),
#  ('Barton Fink', 'Drama'),
#  ('The Last King of Scotland', 'Biography'),
#  ('Adaptation.', 'Comedy'),
#  ('A Very Long Engagement', 'Drama'),
#  ('Mysterious Skin', 'Drama'),
#  ('Stardust', 'Adventure'),
#  ('Black Hawk Down', 'Drama'),
#  ('Paprika', 'Animation'),
#  ('Fear and Loathing in Las Vegas', 'Comedy'),
#  ('Frost/Nixon', 'Drama'),
#  ('Enter the Dragon', 'Action'),
#  ('Short Cuts', 'Comedy'),
#  ("A Hard Day's Night", 'Comedy'),
#  ('The Last Samurai', 'Action'),
#  ('The Station Agent', 'Comedy'),
#  ('Zombieland', 'Comedy'),
#  ('Sympathy for Mr. Vengeance', 'Crime'),
#  ('Despicable Me', 'Animation'),
#  ('Shane', 'Drama'),
#  ('Forbidden Planet', 'Action'),
#  ('Titanic', 'Drama'),
#  ('Gone Baby Gone', 'Crime'),
#  ('The Dinner Game', 'Comedy'),
#  ('Dawn of the Planet of the Apes', 'Action'),
#  ('25th Hour', 'Crime'),
#  ('Ponyo', 'Animation'),
#  ('Shine', 'Biography'),
#  ('The Blind Side', 'Biography'),
#  ('Brokeback Mountain', 'Drama'),
#  ('Cast Away', 'Adventure'),
#  ('Malcolm X', 'Biography'),
#  ('Show Me Love', 'Comedy'),
#  ('Boy A', 'Drama'),
#  ('The Warriors', 'Action'),
#  ('Close Encounters of the Third Kind', 'Drama'),
#  ('Match Point', 'Drama'),
#  ('Training Day', 'Crime'),
#  ('The Butterfly Effect', 'Sci-Fi'),
#  ('The City of Lost Children', 'Fantasy'),
#  ('Billy Elliot', 'Comedy'),
#  ('Love Actually', 'Comedy'),
#  ('The Producers', 'Comedy'),
#  ('Harry Potter and the Deathly Hallows: Part 1', 'Adventure'),
#  ('The Visitor', 'Drama'),
#  ('Philadelphia', 'Drama'),
#  ('Sense and Sensibility', 'Drama'),
#  ('Three Colors: White', 'Comedy'),
#  ('La grande bellezza', 'Drama'),
#  ('Primal Fear', 'Crime'),
#  ('Where Eagles Dare', 'Action'),
#  ('Dazed and Confused', 'Comedy'),
#  ('Blood Simple.', 'Crime'),
#  ('This Is England', 'Crime'),
#  ('Fearless', 'Action'),
#  ('Dangerous Liaisons', 'Drama'),
#  ('Saw', 'Horror'),
#  ('Snow White and the Seven Dwarfs', 'Animation'),
#  ('Coraline', 'Animation'),
#  ('The Hunger Games: Catching Fire', 'Adventure'),
#  ("Sophie's Choice", 'Drama'),
#  ('La Vie en Rose', 'Biography'),
#  ('Star Wars: Episode III - Revenge of the Sith', 'Action'),
#  ('True Grit', 'Adventure'),
#  ('After Hours', 'Comedy'),
#  ('Frozen', 'Animation'),
#  ('Lolita', 'Drama'),
#  ('Eastern Promises', 'Crime'),
#  ('Midnight in Paris', 'Comedy'),
#  ('The Muppet Christmas Carol', 'Comedy'),
#  ('Who Framed Roger Rabbit', 'Animation'),
#  ('Sympathy for Lady Vengeance', 'Crime'),
#  ('Grindhouse', 'Action'),
#  ('In a Better World', 'Drama'),
#  ('Blow-Up', 'Drama'),
#  ('The Secret World of Arrietty', 'Animation'),
#  ('Kiss Kiss Bang Bang', 'Action'),
#  ('Lost Highway', 'Drama'),
#  ('Zodiac', 'Crime'),
#  ('Les Miserables', 'Drama'),
#  ('Moulin Rouge!', 'Drama'),
#  ('Whale Rider', 'Drama'),
#  ('End of Watch', 'Crime'),
#  ('Philomena', 'Biography'),
#  ('Fury', 'Action'),
#  ('The Big Blue', 'Action'),
#  ('First Blood', 'Action'),
#  ('Minority Report', 'Action'),
#  ('Spellbound', 'Film-Noir'),
#  ('The Wicker Man', 'Horror'),
#  ('Seven Pounds', 'Drama'),
#  ('Midnight Express', 'Biography'),
#  ("Kelly's Heroes", 'Action'),
#  ('MASH', 'Comedy'),
#  ('The Player', 'Comedy'),
#  ('Traffic', 'Crime'),
#  ('Y Tu Mama Tambien', 'Drama'),
#  ('Stranger Than Fiction', 'Comedy'),
#  ('Inside Man', 'Crime'),
#  ('127 Hours', 'Adventure'),
#  ('The Fifth Element', 'Action'),
#  ('Milk', 'Biography'),
#  ('United 93', 'Action'),
#  ('Jin ling shi san chai', 'Drama'),
#  ('Dracula', 'Horror'),
#  ('High Plains Drifter', 'Western'),
#  ('I Am Sam', 'Drama'),
#  ('Fried Green Tomatoes', 'Drama'),
#  ('Watchmen', 'Action'),
#  ('28 Days Later...', 'Horror'),
#  ('The Illusionist', 'Drama'),
#  ('Superbad', 'Comedy'),
#  ('The Godfather: Part III', 'Crime'),
#  ('The Royal Tenenbaums', 'Comedy'),
#  ('The Jungle Book', 'Animation'),
#  ('Thank You for Smoking', 'Comedy'),
#  ('Man Bites Dog', 'Comedy'),
#  ('A Few Good Men', 'Drama'),
#  ('The Legend of Drunken Master', 'Action'),
#  ('The Kite Runner', 'Drama'),
#  ('When Harry Met Sally...', 'Comedy'),
#  ('Munich', 'Drama'),
#  ('House of Sand and Fog', 'Drama'),
#  ('Lethal Weapon', 'Action'),
#  ('Animal House', 'Comedy'),
#  ('Lord of War', 'Crime'),
#  ('Blow', 'Biography'),
#  ('Sherlock Holmes', 'Action'),
#  ('Harry Potter and the Goblet of Fire', 'Adventure'),
#  ('La piel que habito', 'Thriller'),
#  ('The Crow', 'Action'),
#  ('West Side Story', 'Crime'),
#  ('The Thin Red Line', 'Drama'),
#  ('American Psycho', 'Crime'),
#  ('The Blind Swordsman: Zatoichi', 'Action'),
#  ('The Last Temptation of Christ', 'Drama'),
#  ('The Naked Gun: From the Files of Police Squad!', 'Comedy'),
#  ('The Others', 'Horror'),
#  ('The Party', 'Comedy'),
#  ('Army of Darkness', 'Comedy'),
#  ('The Hurt Locker', 'Drama'),
#  ('The Raid: Redemption', 'Action'),
#  ('Volver', 'Comedy'),
#  ('Following', 'Mystery'),
#  ('Kung Fu Panda', 'Animation'),
#  ('Mad Max 2: The Road Warrior', 'Action'),
#  ('Jusan-nin no shikaku', 'Action'),
#  ("The Man Who Wasn't There", 'Crime'),
#  ('The Counterfeiters', 'Crime'),
#  ('The Hunt for Red October', 'Action'),
#  ('Lone Survivor', 'Action'),
#  ('A Fish Called Wanda', 'Comedy'),
#  ('The Impossible', 'Drama'),
#  ('Garden State', 'Comedy'),
#  ('Escape from Alcatraz', 'Action'),
#  ('Apollo 13', 'Adventure'),
#  ('Lust, Caution', 'Drama'),
#  ('Selma', 'Biography'),
#  ('Funny Games', 'Crime'),
#  ('The Abyss', 'Adventure'),
#  ('Robin Hood', 'Animation'),
#  ('Enemy at the Gates', 'Drama'),
#  ('Falling Down', 'Crime'),
#  ('Little Children', 'Drama'),
#  ('Hunger', 'Biography'),
#  ('Indiana Jones and the Temple of Doom', 'Action'),
#  ('Ip Man 2', 'Action'),
#  ('The Little Mermaid', 'Animation'),
#  ("It's a Mad, Mad, Mad, Mad World", 'Action'),
#  ('The Reader', 'Drama'),
#  ('The Omen', 'Horror'),
#  ('A Royal Affair', 'Drama'),
#  ('Braindead', 'Comedy'),
#  ('Secondhand Lions', 'Comedy'),
#  ('Disconnect', 'Drama'),
#  ('A Single Man', 'Drama'),
#  ('Hoosiers', 'Drama'),
#  ('Moneyball', 'Biography'),
#  ('The Book Thief', 'Drama'),
#  ('Die Hard: With a Vengeance', 'Action'),
#  ('Interview with the Vampire: The Vampire Chronicles', 'Horror'),
#  ('Midnight Run', 'Action'),
#  ('An American Werewolf in London', 'Comedy'),
#  ('The Great Debaters', 'Biography'),
#  ('Tucker and Dale vs. Evil', 'Comedy'),
#  ('Dead Man Walking', 'Crime'),
#  ('The Piano', 'Drama'),
#  ('The Town', 'Crime'),
#  ('Rise of the Planet of the Apes', 'Action'),
#  ("Boys Don't Cry", 'Biography'),
#  ('Ice Age', 'Animation'),
#  ('Of Mice and Men', 'Drama'),
#  ('Sideways', 'Comedy'),
#  ('High Fidelity', 'Comedy'),
#  ('The Meaning of Life', 'Comedy'),
#  ('Hugo', 'Adventure'),
#  ('Leaving Las Vegas', 'Drama'),
#  ('The Evil Dead', 'Horror'),
#  ('Collateral', 'Crime'),
#  ('Planes, Trains & Automobiles', 'Comedy'),
#  ('Hodejegerne', 'Crime'),
#  ('Field of Dreams', 'Drama'),
#  ('Batman', 'Action'),
#  ('Tell No One', 'Crime'),
#  ('Ghost Dog: The Way of the Samurai', 'Action'),
#  ('Chaplin', 'Biography'),
#  ('Keith', 'Drama'),
#  ('Juno', 'Comedy'),
#  ('The Assassination of Jesse James by the Coward Robert Ford', 'Biography'),
#  ('The Fisher King', 'Comedy'),
#  ('House of Flying Daggers', 'Action'),
#  ('The Hours', 'Drama'),
#  ('The Damned United', 'Biography'),
#  ('Star Trek: First Contact', 'Action'),
#  ('The Natural', 'Drama'),
#  ('The Hobbit: The Battle of the Five Armies', 'Adventure'),
#  ('Equilibrium', 'Action'),
#  ('August Rush', 'Drama'),
#  ('Saving Mr. Banks', 'Biography'),
#  ('The Hurricane', 'Biography'),
#  ("Jacob's Ladder", 'Drama'),
#  ('The Curse of the Were-Rabbit', 'Animation'),
#  ('Christmas Vacation', 'Comedy'),
#  ('Good Night, and Good Luck.', 'Drama'),
#  ('Straw Dogs', 'Crime'),
#  ('42', 'Biography'),
#  ('Rudy', 'Biography'),
#  ('Sleepers', 'Crime'),
#  ('The Wind That Shakes the Barley', 'Drama'),
#  ('Gangs of New York', 'Crime'),
#  ('Elizabeth', 'Biography'),
#  ('Green Street Hooligans', 'Crime'),
#  ('Reign Over Me', 'Drama'),
#  ('RoboCop', 'Action'),
#  ('The Life of David Gale', 'Crime'),
#  ('Life as a House', 'Drama'),
#  ('Despicable Me 2', 'Animation'),
#  ('Jackie Brown', 'Crime'),
#  ('Menace II Society', 'Crime'),
#  ('The Class', 'Drama'),
#  ('Bullets Over Broadway', 'Comedy'),
#  ('American Splendor', 'Biography'),
#  ('Perfume: The Story of a Murderer', 'Crime'),
#  ('Cloud Atlas', 'Drama'),
#  ('Marathon Man', 'Crime'),
#  ('Pinocchio', 'Animation'),
#  ('The Painted Veil', 'Drama'),
#  ('A Simple Plan', 'Crime'),
#  ('The Conjuring', 'Horror'),
#  ('The Man Who Knew Too Much', 'Thriller'),
#  ('Quiz Show', 'Drama'),
#  ('American Graffiti', 'Comedy'),
#  ('The Bridges of Madison County', 'Drama'),
#  ('Gallipoli', 'Adventure'),
#  ("L'illusionniste", 'Animation'),
#  ('Miracle', 'Drama'),
#  ('Maria Full of Grace', 'Crime'),
#  ('Scott Pilgrim vs. the World', 'Action'),
#  ('Pleasantville', 'Comedy'),
#  ('Sherlock Holmes: A Game of Shadows', 'Action'),
#  ('Doubt', 'Drama'),
#  ('The Fly', 'Horror'),
#  ('The Orphanage', 'Drama'),
#  ('Malena', 'Drama'),
#  ('Three Days of the Condor', 'Mystery'),
#  ('[Rec]', 'Horror'),
#  ('A Perfect World', 'Crime'),
#  ('To Catch a Thief', 'Mystery'),
#  ('Best in Show', 'Comedy'),
#  ('Everything Is Illuminated', 'Comedy'),
#  ('A Nightmare on Elm Street', 'Horror'),
#  ('The Ice Storm', 'Drama'),
#  ('X2', 'Action'),
#  ('We Need to Talk About Kevin', 'Drama'),
#  ('Felon', 'Crime'),
#  ('Still Alice', 'Drama'),
#  ('Rust and Bone', 'Drama'),
#  ('Freedom Writers', 'Biography'),
#  ('Legends of the Fall', 'Drama'),
#  ("Buffalo '66", 'Comedy'),
#  ('The Constant Gardener', 'Drama'),
#  ('My Cousin Vinny', 'Comedy'),
#  ('The Texas Chain Saw Massacre', 'Horror'),
#  ('Mulan', 'Animation'),
#  ('A History of Violence', 'Crime'),
#  ('Open Range', 'Action'),
#  ('Total Recall', 'Action'),
#  ('Pi', 'Drama'),
#  ("The Devil's Backbone", 'Drama'),
#  ('The Aviator', 'Biography'),
#  ("Devil's Advocate", 'Drama'),
#  ('The Adventures of Priscilla, Queen of the Desert', 'Comedy'),
#  ('Harry Potter and the Half-Blood Prince', 'Adventure'),
#  ('Fruitvale Station', 'Biography'),
#  ('In the Bedroom', 'Crime'),
#  ('Source Code', 'Mystery'),
#  ('Biutiful', 'Drama'),
#  ('From Russia with Love', 'Action'),
#  ('Calvary', 'Drama'),
#  ('The Mission', 'Adventure'),
#  ('In the Loop', 'Comedy'),
#  ('The Three Burials of Melquiades Estrada', 'Adventure'),
#  ('Babel', 'Drama'),
#  ('Frenzy', 'Thriller'),
#  ('Heavenly Creatures', 'Biography'),
#  ('Sweeney Todd: The Demon Barber of Fleet Street', 'Drama'),
#  ('Dracula', 'Horror'),
#  ('Looper', 'Action'),
#  ('The Proposition', 'Crime'),
#  ('Bullitt', 'Action'),
#  ("Harry Potter and the Sorcerer's Stone", 'Adventure'),
#  ('2046', 'Drama'),
#  ('Transamerica', 'Adventure'),
#  ('Smoke', 'Comedy'),
#  ('Suspiria', 'Horror'),
#  ('The Judge', 'Drama'),
#  ('Bad Education', 'Crime'),
#  ('Up in the Air', 'Drama'),
#  ('Begin Again', 'Drama'),
#  ('Running Scared', 'Action'),
#  ('Ghost World', 'Comedy'),
#  ('Witness', 'Crime'),
#  ('Trading Places', 'Comedy'),
#  ('Mud', 'Drama'),
#  ('Across the Universe', 'Drama'),
#  ('Les Miserables', 'Crime'),
#  ('Notes on a Scandal', 'Drama'),
#  ('Inside Llewyn Davis', 'Drama'),
#  ('Brick', 'Crime'),
#  ('Clerks II', 'Comedy'),
#  ('Say Anything...', 'Comedy'),
#  ('Man on the Moon', 'Biography'),
#  ('Mean Streets', 'Crime'),
#  ('Harry Potter and the Order of the Phoenix', 'Adventure'),
#  ('Beetlejuice', 'Comedy'),
#  ('Crazy, Stupid, Love.', 'Comedy'),
#  ('Excalibur', 'Adventure'),
#  ('True Grit', 'Adventure'),
#  ('Labyrinth', 'Adventure'),
#  ('Alice in Wonderland', 'Animation'),
#  ('Predestination', 'Drama'),
#  ('Much Ado About Nothing', 'Comedy'),
#  ('A Bridge Too Far', 'Drama'),
#  ('Raising Arizona', 'Comedy'),
#  ('The Bucket List', 'Adventure'),
#  ('Terms of Endearment', 'Comedy'),
#  ('Take Shelter', 'Drama'),
#  ('Far from Heaven', 'Drama'),
#  ('Eraserhead', 'Drama'),
#  ('Frances Ha', 'Comedy'),
#  ('Home Alone', 'Comedy'),
#  ('Bound', 'Crime'),
#  ('Sleepy Hollow', 'Drama'),
#  ('Pirate Radio', 'Comedy'),
#  ('The NeverEnding Story', 'Adventure'),
#  ('X-Men', 'Action'),
#  ('Zero Dark Thirty', 'Drama'),
#  ('Manhattan Murder Mystery', 'Comedy'),
#  ("National Lampoon's Vacation", 'Comedy'),
#  ("My Sister's Keeper", 'Drama'),
#  ('Deconstructing Harry', 'Comedy'),
#  ('The Way Way Back', 'Comedy'),
#  ('Capote', 'Biography'),
#  ('Driving Miss Daisy', 'Comedy'),
#  ('La Femme Nikita', 'Action'),
#  ('Lincoln', 'Biography'),
#  ('Limitless', 'Mystery'),
#  ('The Simpsons Movie', 'Animation'),
#  ('The Rock', 'Action'),
#  ('The English Patient', 'Drama'),
#  ('Law Abiding Citizen', 'Crime'),
#  ('Wonder Boys', 'Drama'),
#  ('Death at a Funeral', 'Comedy'),
#  ('Blue Valentine', 'Drama'),
#  ('The Cider House Rules', 'Drama'),
#  ('Tootsie', 'Comedy'),
#  ('Back to the Future Part III', 'Adventure'),
#  ('Master and Commander: The Far Side of the World', 'Action'),
#  ('Poltergeist', 'Horror'),
#  ('Wall Street', 'Crime')]

# %% [markdown]
# `Series`objects can even be modified with a dictionary-like syntax. A `Series` can be extended by assigning to a new index value:

# %%
Genre['Blue Streak'] = 'Comedy'

# %%
Genre.tail()
# Out:
# title
# Back to the Future Part III                        Adventure
# Master and Commander: The Far Side of the World       Action
# Poltergeist                                           Horror
# Wall Street                                            Crime
# Blue Streak                                           Comedy
# Name: genre, dtype: object

# %% [markdown]
# **This easy mutability of the objects abstracts decisions about memory layout and data copying away from the user.**

# %% [markdown]
# A `Series` object also has **array-style** item selection - slicing, masking and fancy indexing.

# %%
# Slicing by explicit index - Note how the Blue Streak index is included

Genre['Poltergeist':'Blue Streak']
# Out:
# title
# Poltergeist    Horror
# Wall Street     Crime
# Blue Streak    Comedy
# Name: genre, dtype: object

# %%
# Slicing by implicit integer index - Note that the 10th index is excluded

Genre[0:10]
# Out:
# title
# The Shawshank Redemption                             Crime
# The Godfather                                        Crime
# The Godfather: Part II                               Crime
# The Dark Knight                                     Action
# Pulp Fiction                                         Crime
# 12 Angry Men                                         Drama
# The Good, the Bad and the Ugly                     Western
# The Lord of the Rings: The Return of the King    Adventure
# Schindler's List                                 Biography
# Fight Club                                           Drama
# Name: genre, dtype: object

# %%
# Boolean indexing

Genre[Genre == 'Sci-Fi']
# Out:
# title
# Blade Runner                     Sci-Fi
# Brazil                           Sci-Fi
# Gravity                          Sci-Fi
# The Day the Earth Stood Still    Sci-Fi
# The Butterfly Effect             Sci-Fi
# Name: genre, dtype: object

# %% [markdown]
# Boolean indexing is the use of boolean vectors to filter the data. For the purposes of pandas, it refers to selecting rows by providing a boolean value (True or False) for each row. The operators are: | for or, & for and, and ~ for not. These __must__ be grouped by using parentheses!

# %%
Genre[(Genre == 'Sci-Fi')|(Genre == 'Film-Noir')]
# Out:
# title
# The Third Man                    Film-Noir
# Blade Runner                        Sci-Fi
# Laura                            Film-Noir
# Brazil                              Sci-Fi
# Gravity                             Sci-Fi
# The Day the Earth Stood Still       Sci-Fi
# The Butterfly Effect                Sci-Fi
# Spellbound                       Film-Noir
# Name: genre, dtype: object

# %%
# Fancy Indexing

Genre[['Fight Club', 'City of God']]
# Out:
# title
# Fight Club     Drama
# City of God    Crime
# Name: genre, dtype: object

# %% [markdown]
# **Question** - What could be a potential problem with both being able to select by both implicit index and explicit index?

# %% [markdown]
# ### Indexer attributes - loc and iloc

# %% [markdown]
# `loc` -  gets rows (or columns) with particular **labels** from the index
# `iloc` -  gets rows (or columns) at particular **positions** in the index
#
# **Note - these were introduced because of the confusion in the case of integer indexes**

# %%
# loc attribute allows indexing and slicing that always references the explicit index

Genre.loc['Blade Runner']
# Out:
# 'Sci-Fi'

# %%
Genre.loc['Pulp Fiction': 'Fight Club']
# Out:
# title
# Pulp Fiction                                         Crime
# 12 Angry Men                                         Drama
# The Good, the Bad and the Ugly                     Western
# The Lord of the Rings: The Return of the King    Adventure
# Schindler's List                                 Biography
# Fight Club                                           Drama
# Name: genre, dtype: object

# %%
# iloc attribute allows indexing and slicing that always references the implicit index

Genre.iloc[145] # Genre.index.get_loc('Blade Runner')
# Out:
# 'Sci-Fi'

# %%
Genre.iloc[4:10]
# Out:
# title
# Pulp Fiction                                         Crime
# 12 Angry Men                                         Drama
# The Good, the Bad and the Ugly                     Western
# The Lord of the Rings: The Return of the King    Adventure
# Schindler's List                                 Biography
# Fight Club                                           Drama
# Name: genre, dtype: object

# %% [markdown]
# ## Data Selection in a `DataFrame`

# %% [markdown]
# **Remember** - A `DataFrame` can be seen to act like a dictionary of `Series` structures sharing the same index.

# %%
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# ### How to select a single column of data as a `Series`

# %%
# Using square bracket notation - most common indexing operator
# pass a single string to the DataFrame indexing operator accesses a column

movies['genre']
# Out:
# title
# The Shawshank Redemption                                 Crime
# The Godfather                                            Crime
# The Godfather: Part II                                   Crime
# The Dark Knight                                         Action
# Pulp Fiction                                             Crime
# 12 Angry Men                                             Drama
# The Good, the Bad and the Ugly                         Western
# The Lord of the Rings: The Return of the King        Adventure
# Schindler's List                                     Biography
# Fight Club                                               Drama
# The Lord of the Rings: The Fellowship of the Ring    Adventure
# Inception                                               Action
# Star Wars: Episode V - The Empire Strikes Back          Action
# Forrest Gump                                             Drama
# The Lord of the Rings: The Two Towers                Adventure
# Interstellar                                         Adventure
# One Flew Over the Cuckoo's Nest                          Drama
# Seven Samurai                                            Drama
# Goodfellas                                           Biography
# Star Wars                                               Action
# The Matrix                                              Action
# City of God                                              Crime
# It's a Wonderful Life                                    Drama
# The Usual Suspects                                       Crime
# Se7en                                                    Drama
# Life Is Beautiful                                       Comedy
# Once Upon a Time in the West                           Western
# The Silence of the Lambs                                 Drama
# Leon: The Professional                                   Crime
# City Lights                                             Comedy
#                                                        ...
# Home Alone                                              Comedy
# Bound                                                    Crime
# Sleepy Hollow                                            Drama
# Pirate Radio                                            Comedy
# The NeverEnding Story                                Adventure
# X-Men                                                   Action
# Zero Dark Thirty                                         Drama
# Manhattan Murder Mystery                                Comedy
# National Lampoon's Vacation                             Comedy
# My Sister's Keeper                                       Drama
# Deconstructing Harry                                    Comedy
# The Way Way Back                                        Comedy
# Capote                                               Biography
# Driving Miss Daisy                                      Comedy
# La Femme Nikita                                         Action
# Lincoln                                              Biography
# Limitless                                              Mystery
# The Simpsons Movie                                   Animation
# The Rock                                                Action
# The English Patient                                      Drama
# Law Abiding Citizen                                      Crime
# Wonder Boys                                              Drama
# Death at a Funeral                                      Comedy
# Blue Valentine                                           Drama
# The Cider House Rules                                    Drama
# Tootsie                                                 Comedy
# Back to the Future Part III                          Adventure
# Master and Commander: The Far Side of the World         Action
# Poltergeist                                             Horror
# Wall Street                                              Crime
# Name: genre, Length: 979, dtype: object

# %%
# Alternative method - using dot notation and accessing an attribute

movies.genre
# Out:
# title
# The Shawshank Redemption                                 Crime
# The Godfather                                            Crime
# The Godfather: Part II                                   Crime
# The Dark Knight                                         Action
# Pulp Fiction                                             Crime
# 12 Angry Men                                             Drama
# The Good, the Bad and the Ugly                         Western
# The Lord of the Rings: The Return of the King        Adventure
# Schindler's List                                     Biography
# Fight Club                                               Drama
# The Lord of the Rings: The Fellowship of the Ring    Adventure
# Inception                                               Action
# Star Wars: Episode V - The Empire Strikes Back          Action
# Forrest Gump                                             Drama
# The Lord of the Rings: The Two Towers                Adventure
# Interstellar                                         Adventure
# One Flew Over the Cuckoo's Nest                          Drama
# Seven Samurai                                            Drama
# Goodfellas                                           Biography
# Star Wars                                               Action
# The Matrix                                              Action
# City of God                                              Crime
# It's a Wonderful Life                                    Drama
# The Usual Suspects                                       Crime
# Se7en                                                    Drama
# Life Is Beautiful                                       Comedy
# Once Upon a Time in the West                           Western
# The Silence of the Lambs                                 Drama
# Leon: The Professional                                   Crime
# City Lights                                             Comedy
#                                                        ...
# Home Alone                                              Comedy
# Bound                                                    Crime
# Sleepy Hollow                                            Drama
# Pirate Radio                                            Comedy
# The NeverEnding Story                                Adventure
# X-Men                                                   Action
# Zero Dark Thirty                                         Drama
# Manhattan Murder Mystery                                Comedy
# National Lampoon's Vacation                             Comedy
# My Sister's Keeper                                       Drama
# Deconstructing Harry                                    Comedy
# The Way Way Back                                        Comedy
# Capote                                               Biography
# Driving Miss Daisy                                      Comedy
# La Femme Nikita                                         Action
# Lincoln                                              Biography
# Limitless                                              Mystery
# The Simpsons Movie                                   Animation
# The Rock                                                Action
# The English Patient                                      Drama
# Law Abiding Citizen                                      Crime
# Wonder Boys                                              Drama
# Death at a Funeral                                      Comedy
# Blue Valentine                                           Drama
# The Cider House Rules                                    Drama
# Tootsie                                                 Comedy
# Back to the Future Part III                          Adventure
# Master and Commander: The Far Side of the World         Action
# Poltergeist                                             Horror
# Wall Street                                              Crime
# Name: genre, Length: 979, dtype: object

# %% [markdown]
# **Dot notation not best practice!**
#
# -  Column names with spaces/special characters can not be accessed
# -  Column names that are also `DataFrame` methods fail to be selected correctly using dot notation.
#
# However, dot notation is still very commonly used ....... because laziness!

# %%
# example - add a column to dataframe called head
# Like with the Series objects from above, dictionary-style syntax can also be used to modify the object
# example - adding a new column

movies['head'] = np.random.randint(0, 1000, movies.shape[0])
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list  \
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
#                           head
# title
# The Shawshank Redemption   977
# The Godfather              664
# The Godfather: Part II     465
# The Dark Knight            452
# Pulp Fiction               617

# %%
# check for equality between object returned by dot notation and by square brackets

movies.head is movies['head']
# Out:
# False

# %% [markdown]
# We can also view the `DataFrame` as an enhanced two-dimensional array.
# We can examine the raw underlying data array using the `values` attribute:

# %%
movies.values
# Out:
# array([[9.3, 'R', 'Crime', 142,
#         "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']", 977],
#        [9.2, 'R', 'Crime', 175,
#         "[u'Marlon Brando', u'Al Pacino', u'James Caan']", 664],
#        [9.1, 'R', 'Crime', 200,
#         "[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']", 465],
#        ...,
#        [7.4, 'PG-13', 'Action', 138,
#         "[u'Russell Crowe', u'Paul Bettany', u'Billy Boyd']", 583],
#        [7.4, 'PG', 'Horror', 114,
#         '[u\'JoBeth Williams\', u"Heather O\'Rourke", u\'Craig T. Nelson\']',
#         211],
#        [7.4, 'R', 'Crime', 126,
#         "[u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']", 547]],
#       dtype=object)

# %% [markdown]
# This allows many familiar array-like observations to be performed on the `DataFrame` itself

# %%
# Example = Transpose a dataframe

movies.T
# Out:
# title                                    The Shawshank Redemption  \
# star_rating                                                   9.3
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      142
# actors_list     [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# head                                                          977
#
# title                                             The Godfather  \
# star_rating                                                 9.2
# content_rating                                                R
# genre                                                     Crime
# duration                                                    175
# actors_list     [u'Marlon Brando', u'Al Pacino', u'James Caan']
# head                                                        664
#
# title                                      The Godfather: Part II  \
# star_rating                                                   9.1
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      200
# actors_list     [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# head                                                          465
#
# title                                             The Dark Knight  \
# star_rating                                                     9
# content_rating                                              PG-13
# genre                                                      Action
# duration                                                      152
# actors_list     [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# head                                                          452
#
# title                                                Pulp Fiction  \
# star_rating                                                   8.9
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      154
# actors_list     [u'John Travolta', u'Uma Thurman', u'Samuel L....
# head                                                          617
#
# title                                                12 Angry Men  \
# star_rating                                                   8.9
# content_rating                                          NOT RATED
# genre                                                       Drama
# duration                                                       96
# actors_list     [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# head                                                           42
#
# title                              The Good, the Bad and the Ugly  \
# star_rating                                                   8.9
# content_rating                                          NOT RATED
# genre                                                     Western
# duration                                                      161
# actors_list     [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# head                                                          951
#
# title               The Lord of the Rings: The Return of the King  \
# star_rating                                                   8.9
# content_rating                                              PG-13
# genre                                                   Adventure
# duration                                                      201
# actors_list     [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# head                                                          663
#
# title                                            Schindler's List  \
# star_rating                                                   8.9
# content_rating                                                  R
# genre                                                   Biography
# duration                                                      195
# actors_list     [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# head                                                          168
#
# title                                                  Fight Club  \
# star_rating                                                   8.9
# content_rating                                                  R
# genre                                                       Drama
# duration                                                      139
# actors_list     [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# head                                                          253
#
# title           The Lord of the Rings: The Fellowship of the Ring  \
# star_rating                                                   8.8
# content_rating                                              PG-13
# genre                                                   Adventure
# duration                                                      178
# actors_list     [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# head                                                          247
#
# title                                                   Inception  \
# star_rating                                                   8.8
# content_rating                                              PG-13
# genre                                                      Action
# duration                                                      148
# actors_list     [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# head                                                          563
#
# title              Star Wars: Episode V - The Empire Strikes Back  \
# star_rating                                                   8.8
# content_rating                                                 PG
# genre                                                      Action
# duration                                                      124
# actors_list     [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# head                                                          726
#
# title                                              Forrest Gump  \
# star_rating                                                 8.8
# content_rating                                            PG-13
# genre                                                     Drama
# duration                                                    142
# actors_list     [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# head                                                        431
#
# title                       The Lord of the Rings: The Two Towers  \
# star_rating                                                   8.8
# content_rating                                              PG-13
# genre                                                   Adventure
# duration                                                      179
# actors_list     [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# head                                                          833
#
# title                                                Interstellar  \
# star_rating                                                   8.7
# content_rating                                              PG-13
# genre                                                   Adventure
# duration                                                      169
# actors_list     [u'Matthew McConaughey', u'Anne Hathaway', u'J...
# head                                                          535
#
# title                             One Flew Over the Cuckoo's Nest  \
# star_rating                                                   8.7
# content_rating                                                  R
# genre                                                       Drama
# duration                                                      133
# actors_list     [u'Jack Nicholson', u'Louise Fletcher', u'Mich...
# head                                                           15
#
# title                                               Seven Samurai  \
# star_rating                                                   8.7
# content_rating                                            UNRATED
# genre                                                       Drama
# duration                                                      207
# actors_list     [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# head                                                          170
#
# title                                                 Goodfellas  \
# star_rating                                                  8.7
# content_rating                                                 R
# genre                                                  Biography
# duration                                                     146
# actors_list     [u'Robert De Niro', u'Ray Liotta', u'Joe Pesci']
# head                                                         954
#
# title                                                   Star Wars  \
# star_rating                                                   8.7
# content_rating                                                 PG
# genre                                                      Action
# duration                                                      121
# actors_list     [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# head                                                          773
#
# title                                                  The Matrix  \
# star_rating                                                   8.7
# content_rating                                                  R
# genre                                                      Action
# duration                                                      136
# actors_list     [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# head                                                          673
#
# title                                                 City of God  \
# star_rating                                                   8.7
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      130
# actors_list     [u'Alexandre Rodrigues', u'Matheus Nachtergael...
# head                                                          947
#
# title                                       It's a Wonderful Life  \
# star_rating                                                   8.7
# content_rating                                           APPROVED
# genre                                                       Drama
# duration                                                      130
# actors_list     [u'James Stewart', u'Donna Reed', u'Lionel Bar...
# head                                                          968
#
# title                                          The Usual Suspects  \
# star_rating                                                   8.7
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      106
# actors_list     [u'Kevin Spacey', u'Gabriel Byrne', u'Chazz Pa...
# head                                                          413
#
# title                                                       Se7en  \
# star_rating                                                   8.7
# content_rating                                                  R
# genre                                                       Drama
# duration                                                      127
# actors_list     [u'Morgan Freeman', u'Brad Pitt', u'Kevin Spac...
# head                                                          870
#
# title                                 ...                          \
# star_rating                           ...
# content_rating                        ...
# genre                                 ...
# duration                              ...
# actors_list                           ...
# head                                  ...
#
# title                                                       X-Men  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                      Action
# duration                                                      104
# actors_list     [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# head                                                          869
#
# title                                            Zero Dark Thirty  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                       Drama
# duration                                                      157
# actors_list     [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# head                                                          430
#
# title                                    Manhattan Murder Mystery  \
# star_rating                                                   7.4
# content_rating                                                 PG
# genre                                                      Comedy
# duration                                                      104
# actors_list     [u'Woody Allen', u'Diane Keaton', u'Jerry Adler']
# head                                                          336
#
# title                                 National Lampoon's Vacation  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                      Comedy
# duration                                                       98
# actors_list     [u'Chevy Chase', u"Beverly D'Angelo", u'Imogen...
# head                                                          660
#
# title                                          My Sister's Keeper  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                       Drama
# duration                                                      109
# actors_list     [u'Cameron Diaz', u'Abigail Breslin', u'Alec B...
# head                                                          979
#
# title                                        Deconstructing Harry  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                      Comedy
# duration                                                       96
# actors_list     [u'Woody Allen', u'Judy Davis', u'Julia Louis-...
# head                                                          368
#
# title                                            The Way Way Back  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                      Comedy
# duration                                                      103
# actors_list     [u'Steve Carell', u'Toni Collette', u'Allison ...
# head                                                          928
#
# title                                                      Capote  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                   Biography
# duration                                                      114
# actors_list     [u'Philip Seymour Hoffman', u'Clifton Collins ...
# head                                                          846
#
# title                                          Driving Miss Daisy  \
# star_rating                                                   7.4
# content_rating                                                 PG
# genre                                                      Comedy
# duration                                                       99
# actors_list     [u'Morgan Freeman', u'Jessica Tandy', u'Dan Ay...
# head                                                          624
#
# title                                             La Femme Nikita  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                      Action
# duration                                                      118
# actors_list     [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# head                                                          167
#
# title                                                     Lincoln  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                   Biography
# duration                                                      150
# actors_list     [u'Daniel Day-Lewis', u'Sally Field', u'David ...
# head                                                          753
#
# title                                                   Limitless  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                     Mystery
# duration                                                      105
# actors_list     [u'Bradley Cooper', u'Anna Friel', u'Abbie Cor...
# head                                                          161
#
# title                                          The Simpsons Movie  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                   Animation
# duration                                                       87
# actors_list     [u'Dan Castellaneta', u'Julie Kavner', u'Nancy...
# head                                                          584
#
# title                                                   The Rock  \
# star_rating                                                  7.4
# content_rating                                                 R
# genre                                                     Action
# duration                                                     136
# actors_list     [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# head                                                         377
#
# title                                         The English Patient  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                       Drama
# duration                                                      162
# actors_list     [u'Ralph Fiennes', u'Juliette Binoche', u'Will...
# head                                                          539
#
# title                                         Law Abiding Citizen  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      109
# actors_list     [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# head                                                          935
#
# title                                                 Wonder Boys  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                       Drama
# duration                                                      107
# actors_list     [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# head                                                          129
#
# title                                          Death at a Funeral  \
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                      Comedy
# duration                                                       90
# actors_list     [u'Matthew Macfadyen', u'Peter Dinklage', u'Ew...
# head                                                          898
#
# title                                              Blue Valentine  \
# star_rating                                                   7.4
# content_rating                                              NC-17
# genre                                                       Drama
# duration                                                      112
# actors_list     [u'Ryan Gosling', u'Michelle Williams', u'John...
# head                                                          177
#
# title                                       The Cider House Rules  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                       Drama
# duration                                                      126
# actors_list     [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# head                                                          259
#
# title                                                     Tootsie  \
# star_rating                                                   7.4
# content_rating                                                 PG
# genre                                                      Comedy
# duration                                                      116
# actors_list     [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# head                                                          805
#
# title                                 Back to the Future Part III  \
# star_rating                                                   7.4
# content_rating                                                 PG
# genre                                                   Adventure
# duration                                                      118
# actors_list     [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# head                                                          866
#
# title             Master and Commander: The Far Side of the World  \
# star_rating                                                   7.4
# content_rating                                              PG-13
# genre                                                      Action
# duration                                                      138
# actors_list     [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# head                                                          583
#
# title                                                 Poltergeist  \
# star_rating                                                   7.4
# content_rating                                                 PG
# genre                                                      Horror
# duration                                                      114
# actors_list     [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# head                                                          211
#
# title                                                 Wall Street
# star_rating                                                   7.4
# content_rating                                                  R
# genre                                                       Crime
# duration                                                      126
# actors_list     [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# head                                                          547
#
# [6 rows x 979 columns]

# %% [markdown]
# For array-style indexing, we use the``loc``and``iloc``indexers mentioned earlier.

# %%
# Remove the previously created head column

del movies['head']

# %%
# For label specific indexing using the explicit index and column names

movies.loc[['The Godfather', 'Pulp Fiction'],['genre', 'duration']]
# Out:
#                genre  duration
# title
# The Godfather  Crime       175
# Pulp Fiction   Crime       154

# %%
# For non label specific indexing using the implicit index

movies.iloc[:4, 1:5]

# Note how the index and column names are maintained
# Out:
#                          content_rating   genre  duration  \
# title
# The Shawshank Redemption              R   Crime       142
# The Godfather                         R   Crime       175
# The Godfather: Part II                R   Crime       200
# The Dark Knight                   PG-13  Action       152
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %% [markdown]
# Any of the previously mentioned`Series`style data access patterns can be used within these indexers.
# For example, in the``loc``indexer we can combine masking and fancy indexing:

# %%
movies.loc[movies.duration > 220, ['duration', 'star_rating']]
# Out:
#                                    duration  star_rating
# title
# Once Upon a Time in America             229          8.4
# Lagaan: Once Upon a Time in India       224          8.3
# Gone with the Wind                      238          8.2
# Hamlet                                  242          7.8

# %% [markdown]
# ## Recipe: Constructing multiple boolean conditions

# %% [markdown]
# Constructing a precise filter for your dataset  might have you combining multiple boolean expressions together to extract an exact subset.
#
# **Aim:** Find all movies that have a **star_rating** over 8.5 in the Action or Adventure genres.

# %% [markdown]
# **Solution:** Construct and combine multiple boolean expressions

# %%
# Usually we would load in our dataset, but we already have it in the variable movies

movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# Create a variable to hold each set of criteria independently as a boolean Series

star_8 = movies['star_rating'] > 8.5
action_adventure = (movies['genre'] == 'Action') | (movies['genre'] == 'Adventure')

# Note the use of parenthesis and the pandas or operator

# %%
# Combine all the criteria together into a single boolean Series:

criteria = star_8 & action_adventure

criteria.head()

# Use of the pandas and operator
# Out:
# title
# The Shawshank Redemption    False
# The Godfather               False
# The Godfather: Part II      False
# The Dark Knight              True
# Pulp Fiction                False
# dtype: bool

# %%
# Once you have your boolean Series, you simply pass it to the indexing operator to filter the data:

movies[criteria].head()
# Out:
#                                                    star_rating content_rating  \
# title
# The Dark Knight                                            9.0          PG-13
# The Lord of the Rings: The Return of the King              8.9          PG-13
# The Lord of the Rings: The Fellowship of the Ring          8.8          PG-13
# Inception                                                  8.8          PG-13
# Star Wars: Episode V - The Empire Strikes Back             8.8             PG
#
#                                                        genre  duration  \
# title
# The Dark Knight                                       Action       152
# The Lord of the Rings: The Return of the King      Adventure       201
# The Lord of the Rings: The Fellowship of the Ring  Adventure       178
# Inception                                             Action       148
# Star Wars: Episode V - The Empire Strikes Back        Action       124
#
#                                                                                          actors_list
# title
# The Dark Knight                                    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# The Lord of the Rings: The Return of the King      [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# The Lord of the Rings: The Fellowship of the Ring  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# Inception                                          [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# Star Wars: Episode V - The Empire Strikes Back     [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...

# %%
movies.loc[criteria, ['star_rating', 'genre']]
# Out:
#                                                    star_rating      genre
# title
# The Dark Knight                                            9.0     Action
# The Lord of the Rings: The Return of the King              8.9  Adventure
# The Lord of the Rings: The Fellowship of the Ring          8.8  Adventure
# Inception                                                  8.8     Action
# Star Wars: Episode V - The Empire Strikes Back             8.8     Action
# The Lord of the Rings: The Two Towers                      8.8  Adventure
# Interstellar                                               8.7  Adventure
# Star Wars                                                  8.7     Action
# The Matrix                                                 8.7     Action
# Saving Private Ryan                                        8.6     Action
# Raiders of the Lost Ark                                    8.6     Action

# %% [markdown]
# ## Exercises
# ***

# %%
# We will cover methods in a future section but to help with these exercises the 'unique' method can be called on a Series 
# to understand the unique values that it contains

movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# __1)__ You are a parent with four children under 6 who were promised to be able to watch a film before bedtime. The film has to be content rated PG and within the 'Family' genre. What film do you pick?

# %% [markdown]
# __2)__ You are a child who has been given permission to watch __any__ film as long as it is age appropriate (content rating PG or PG-13). You would also like to stay up as late as possible, so you would like the longest film available (at least 3 hours), what do you pick?

# %% [markdown]
# __3)__ What's the best R rated film from the movies`DataFrame`that isn't in the Drama, Comedy, Action or Crime genres? Note - the movies`DataFrame`is already sorted by star_rating.

# %% [markdown]
# __Advanced Questions__

# %% [markdown]
# __4)__ Select all movies in the `DataFrame` that have a title that starts with 'The'?
# **Help** - [**`String Methods`**](https://pandas.pydata.org/pandas-docs/stable/text.html)

# %% [markdown]
# # Potential Pitfalls
#
# ## SettingWithCopyWarning

# %%
# examine the DataFrame rows that contain missing values
movies[movies.content_rating.isnull()]
# Out:
#                                     star_rating content_rating      genre  \
# title
# Butch Cassidy and the Sundance Kid          8.2            NaN  Biography
# Where Eagles Dare                           7.7            NaN     Action
# True Grit                                   7.4            NaN  Adventure
#
#                                     duration  \
# title
# Butch Cassidy and the Sundance Kid       110
# Where Eagles Dare                        158
# True Grit                                128
#
#                                                                           actors_list
# title
# Butch Cassidy and the Sundance Kid  [u'Paul Newman', u'Robert Redford', u'Katharin...
# Where Eagles Dare                   [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# True Grit                             [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
# examine the unique values in the 'content_rating' Series
movies.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# **Aim:** Mark the 'NOT RATED' values as missing values, represented by 'NaN'.

# %%
# first, locate the relevant rows
movies[movies.content_rating=='NOT RATED'].head()
# Out:
#                                 star_rating content_rating    genre  duration  \
# title
# 12 Angry Men                            8.9      NOT RATED    Drama        96
# The Good, the Bad and the Ugly          8.9      NOT RATED  Western       161
# Sunset Blvd.                            8.5      NOT RATED    Drama       110
# M                                       8.4      NOT RATED    Crime        99
# Munna Bhai M.B.B.S.                     8.4      NOT RATED   Comedy       156
#
#                                                                       actors_list
# title
# 12 Angry Men                    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# The Good, the Bad and the Ugly  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# Sunset Blvd.                    [u'William Holden', u'Gloria Swanson', u'Erich...
# M                               [u'Peter Lorre', u'Ellen Widmann', u'Inge Land...
# Munna Bhai M.B.B.S.              [u'Sunil Dutt', u'Sanjay Dutt', u'Arshad Warsi']

# %%
# then, select the 'content_rating' Series from those rows
movies[movies.content_rating=='NOT RATED'].content_rating.head()
# Out:
# title
# 12 Angry Men                      NOT RATED
# The Good, the Bad and the Ugly    NOT RATED
# Sunset Blvd.                      NOT RATED
# M                                 NOT RATED
# Munna Bhai M.B.B.S.               NOT RATED
# Name: content_rating, dtype: object

# %%
# finally, replace the 'NOT RATED' values with 'NaN'

movies[movies.content_rating=='NOT RATED'].content_rating = np.nan
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# **Problem:** That statement involves two operations, a **`__getitem__`** and a **`__setitem__`**. Pandas can't guarantee whether the **`__getitem__`** operation returns a view or a copy of the data.
#
# - If **`__getitem__`** returns a view of the data, **`__setitem__`** will affect the 'movies' DataFrame.
# - But if **`__getitem__`** returns a copy of the data, **`__setitem__`** will not affect the 'movies' DataFrame.

# %% [markdown]
# **Solution:** Use the **`loc`** method, which replaces the 'NOT RATED' values in a single **`__setitem__`** operation.

# %%
# replace the 'NOT RATED' values with 'NaN' (does not cause a SettingWithCopyWarning)
movies.loc[movies.content_rating=='NOT RATED', 'content_rating'] = np.nan

# %%
# this time, the 'content_rating' Series has changed
movies.content_rating.isnull().sum()
# Out:
# 68

# %% [markdown]
# ### Second Instance

# %%
# create a DataFrame only containing movies with a high 'star_rating'
top_movies = movies.loc[movies.star_rating >= 9, :]
top_movies
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
# overwrite the relevant cell with the correct duration
top_movies.loc['The Shawshank Redemption', 'duration'] = 150
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# **Problem:** pandas isn't sure whether 'top_movies' is a view or a copy of 'movies'.

# %%
# 'top_movies' DataFrame has been updated
top_movies
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       150
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
# 'movies' DataFrame has not been updated
movies.head(1)
# Out:
#                           star_rating content_rating  genre  duration  \
# title
# The Shawshank Redemption          9.3              R  Crime       142
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %% [markdown]
# **Solution:** Any time you are attempting to create a DataFrame copy, use the copy method.

# %%
# explicitly create a copy of 'movies'
top_movies = movies.loc[movies.star_rating >= 9, :].copy()

# %%
# pandas now knows that you are updating a copy instead of a view (does not cause a SettingWithCopyWarning)
top_movies.loc['The Shawshank Redemption', 'duration'] = 150

# %%
# 'top_movies' DataFrame has been updated
top_movies
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       150
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %% [markdown]
# # Recap
# ***
#
# 1. `Series` and `DataFrames` can be manipulated in a similar fashion to both dictionaries and arrays. The main index operator is a square bracket.
#
#
# 2. Pandas data structures have both implicit and explicit indices, which can be used for data selection.
#
#
# 3. The `loc` and `iloc` indexing operators are considered best practice for both the selection of data and when assigning new values to a `DataFram/Series`.
#
#     -  `loc` provides label based indexing
#     -  `iloc` provides position based indexing
#
#
# 4. Boolean indexing, with multiple criteria can be performed with both `loc` and `[]` indexing.
#
#
# 5. `SettingWithCopyWarning` error message a result of Pandas not knowing if a view of data is being requested or a copy. Best practice is to explicitly copy if required.

# %% [markdown]
# <!--NAVIGATION-->
# < [Pandas IO](03_Pandas_Data_IO.ipynb) | [Contents](Index.ipynb) | [Essential Pandas Functionality](05_Pandas_EssentialFunctionality.ipynb) >
