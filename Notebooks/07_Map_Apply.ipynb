# %% [markdown]
# # Applying functions to pandas `Series` or `DataFrames`

# %%
## Base imports

import pandas as pd
import numpy as np
pd.set_option('max_columns', 50)

# %%
# read the titanic dataset from Kaggle's Titanic competition into a DataFrame
titanic = pd.read_csv('./Data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Aim:** Map the existing values of a Series to a different set of values
#
# **Method:** [**`map`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) (Series method)

# %%
# map 'female' to 0 and 'male' to 1
titanic['Sex_num'] = titanic.Sex.map({'female':0, 'male':1})
titanic.loc[0:4, ['Sex', 'Sex_num']]
# Out:
#       Sex  Sex_num
# 0    male        1
# 1  female        0
# 2  female        0
# 3  female        0
# 4    male        1

# %% [markdown]
# **Aim:** Apply a function to each element in a Series
#
# **Method:** [**`apply`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html) (Series method)
#
# **Note:** **`map`** can be substituted for **`apply`** in many cases, but **`apply`** is more flexible and thus is recommended

# %%
# calculate the length of each string in the 'Name' Series
titanic['Name_length'] = titanic.Name.apply(len)
titanic.loc[0:4, ['Name', 'Name_length']]
# Out:
#                                                 Name  Name_length
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                             Heikkinen, Miss. Laina           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                           Allen, Mr. William Henry           24

# %%
# round up each element in the 'Fare' Series to the next integer
titanic['Fare_ceil'] = titanic.Fare.apply(np.ceil)
titanic.loc[0:4, ['Fare', 'Fare_ceil']]
# Out:
#       Fare  Fare_ceil
# 0   7.2500        8.0
# 1  71.2833       72.0
# 2   7.9250        8.0
# 3  53.1000       54.0
# 4   8.0500        9.0

# %%
# we want to extract the last name of each person
titanic.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# use a string method to split the 'Name' Series at commas (returns a Series of lists)
titanic.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
# define a function that returns an element from a list based on position
def get_element(my_list, position):
    return my_list[position]

# %%
# apply the 'get_element' function and pass 'position' as a keyword argument
titanic.Name.str.split(',').apply(get_element, position=0).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
# alternatively, use a lambda function
titanic.Name.str.split(',').apply(lambda x: x[0]).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %% [markdown]
# **Aim:** Apply a function along either axis of a `DataFrame`
#
# **Method:** [**`apply`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.apply.html) (DataFrame method)

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('./Data/alcohol.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# select a subset of the DataFrame to work with
drinks.loc[:, 'beer_servings':'wine_servings'].head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45

# %%
# apply the 'max' function along axis 0 to calculate the maximum value in each column
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
# apply the 'max' function along axis 1 to calculate the maximum value in each row
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=1).head()
# Out:
# 0      0
# 1    132
# 2     25
# 3    312
# 4    217
# dtype: int64

# %%
# use 'np.argmax' to calculate which column has the maximum value for each row
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis=1).head()
# Out:
# 0      beer_servings
# 1    spirit_servings
# 2      beer_servings
# 3      wine_servings
# 4      beer_servings
# dtype: object

# %% [markdown]
# **Aim:** Apply a function to every element in a `DataFrame`
#
# **Method:** [**`applymap`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.applymap.html) (DataFrame method)

# %%
# convert every DataFrame element into a float
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float).head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          245.0            138.0          312.0
# 4          217.0             57.0           45.0

# %%
# overwrite the existing DataFrame columns
drinks.loc[:, 'beer_servings':'wine_servings'] = drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ## Exercises
# ***

# %% [markdown]
# __1)__ For each country in the alcohol dataset, what beverage has the minimum average consumption per person (beer, wine or spirits)? Add results as a new column.

# %% [markdown]
# __2)__ Calculate the difference in average servings between the most popular beverage and the least popular beverage for each country. Which country has the highest difference?

# %% [markdown]
# __3)__ For the titanic dataset, add a new column that shows the number of travellers travelling on each ticket.

# %% [markdown]
# # Recap
# ***
#
# 1. Map/Apply allow for functions to be applied across Pandas data structures. Extremely useful when a vectorised method does not natively exist.
#
#
# 2. **map** `Series` method - Map the existing values of a Series to a different set of values.
#
#
# 3. **apply** `Series` method - Apply a function to each element in a Series.
#
#
# 4. **apply** `DataFrame` method - Apply a function along either axis of a `DataFrame`.
#
#
# 5. **applymap** `DataFrame` method - Apply a function to every element in a `DataFrame`

# %% [markdown]
#  # __Further Reading__

# %% [markdown]
# ## [Group By: split-apply-combine](https://pandas.pydata.org/pandas-docs/stable/groupby.html)

# %%
# Example

drinks.groupby('continent').agg([np.mean, lambda x: x.min()])
# Out:
#               beer_servings          spirit_servings          wine_servings  \
#                        mean <lambda>            mean <lambda>          mean
# continent
# Africa            61.471698      0.0       16.339623      0.0     16.264151
# Asia              37.045455      0.0       60.840909      0.0      9.068182
# Europe           193.777778      0.0      132.555556      0.0    142.222222
# North America    145.434783      1.0      165.739130     68.0     24.521739
# Oceania           89.687500      0.0       58.437500      0.0     35.625000
# South America    175.083333     93.0      114.750000     25.0     62.416667
#
#                        total_litres_of_pure_alcohol                 diff  \
#               <lambda>                         mean <lambda>        mean
# continent
# Africa             0.0                     3.007547      0.0   61.433962
# Asia               0.0                     2.170455      0.0   67.454545
# Europe             0.0                     8.617778      0.0  160.222222
# North America      1.0                     5.995652      2.2  178.521739
# Oceania            0.0                     3.381250      0.0   94.125000
# South America      1.0                     6.308333      3.8  184.583333
#
#
#               <lambda>
# continent
# Africa             0.0
# Asia               0.0
# Europe             0.0
# North America     67.0
# Oceania            0.0
# South America     48.0

# %% [markdown]
# ## [Reshaping & Pivot Tables](https://pandas.pydata.org/pandas-docs/stable/reshaping.html)

# %%
# Example

drinks.pivot('continent', 'country', 'total_litres_of_pure_alcohol')
# Out:
# country        Afghanistan  Albania  Algeria  Andorra  Angola  \
# continent
# Africa                 NaN      NaN      0.7      NaN     5.9
# Asia                   0.0      NaN      NaN      NaN     NaN
# Europe                 NaN      4.9      NaN     12.4     NaN
# North America          NaN      NaN      NaN      NaN     NaN
# Oceania                NaN      NaN      NaN      NaN     NaN
# South America          NaN      NaN      NaN      NaN     NaN
#
# country        Antigua & Barbuda  Argentina  Armenia  Australia  Austria  \
# continent
# Africa                       NaN        NaN      NaN        NaN      NaN
# Asia                         NaN        NaN      NaN        NaN      NaN
# Europe                       NaN        NaN      3.8        NaN      9.7
# North America                4.9        NaN      NaN        NaN      NaN
# Oceania                      NaN        NaN      NaN       10.4      NaN
# South America                NaN        8.3      NaN        NaN      NaN
#
# country        Azerbaijan  Bahamas  Bahrain  Bangladesh  Barbados  Belarus  \
# continent
# Africa                NaN      NaN      NaN         NaN       NaN      NaN
# Asia                  NaN      NaN      2.0         0.0       NaN      NaN
# Europe                1.3      NaN      NaN         NaN       NaN     14.4
# North America         NaN      6.3      NaN         NaN       6.3      NaN
# Oceania               NaN      NaN      NaN         NaN       NaN      NaN
# South America         NaN      NaN      NaN         NaN       NaN      NaN
#
# country        Belgium  Belize  Benin  Bhutan  Bolivia  Bosnia-Herzegovina  \
# continent
# Africa             NaN     NaN    1.1     NaN      NaN                 NaN
# Asia               NaN     NaN    NaN     0.4      NaN                 NaN
# Europe            10.5     NaN    NaN     NaN      NaN                 4.6
# North America      NaN     6.8    NaN     NaN      NaN                 NaN
# Oceania            NaN     NaN    NaN     NaN      NaN                 NaN
# South America      NaN     NaN    NaN     NaN      3.8                 NaN
#
# country        Botswana  Brazil  Brunei    ...     Syria  Tajikistan  \
# continent                                  ...
# Africa              5.4     NaN     NaN    ...       NaN         NaN
# Asia                NaN     NaN     0.6    ...       1.0         0.3
# Europe              NaN     NaN     NaN    ...       NaN         NaN
# North America       NaN     NaN     NaN    ...       NaN         NaN
# Oceania             NaN     NaN     NaN    ...       NaN         NaN
# South America       NaN     7.2     NaN    ...       NaN         NaN
#
# country        Tanzania  Thailand  Timor-Leste  Togo  Tonga  \
# continent
# Africa              5.7       NaN          NaN   1.3    NaN
# Asia                NaN       6.4          0.1   NaN    NaN
# Europe              NaN       NaN          NaN   NaN    NaN
# North America       NaN       NaN          NaN   NaN    NaN
# Oceania             NaN       NaN          NaN   NaN    1.1
# South America       NaN       NaN          NaN   NaN    NaN
#
# country        Trinidad & Tobago  Tunisia  Turkey  Turkmenistan  Tuvalu  USA  \
# continent
# Africa                       NaN      1.3     NaN           NaN     NaN  NaN
# Asia                         NaN      NaN     1.4           2.2     NaN  NaN
# Europe                       NaN      NaN     NaN           NaN     NaN  NaN
# North America                6.4      NaN     NaN           NaN     NaN  8.7
# Oceania                      NaN      NaN     NaN           NaN     1.0  NaN
# South America                NaN      NaN     NaN           NaN     NaN  NaN
#
# country        Uganda  Ukraine  United Arab Emirates  United Kingdom  Uruguay  \
# continent
# Africa            8.3      NaN                   NaN             NaN      NaN
# Asia              NaN      NaN                   2.8             NaN      NaN
# Europe            NaN      8.9                   NaN            10.4      NaN
# North America     NaN      NaN                   NaN             NaN      NaN
# Oceania           NaN      NaN                   NaN             NaN      NaN
# South America     NaN      NaN                   NaN             NaN      6.6
#
# country        Uzbekistan  Vanuatu  Venezuela  Vietnam  Yemen  Zambia  \
# continent
# Africa                NaN      NaN        NaN      NaN    NaN     2.5
# Asia                  2.4      NaN        NaN      2.0    0.1     NaN
# Europe                NaN      NaN        NaN      NaN    NaN     NaN
# North America         NaN      NaN        NaN      NaN    NaN     NaN
# Oceania               NaN      0.9        NaN      NaN    NaN     NaN
# South America         NaN      NaN        7.7      NaN    NaN     NaN
#
# country        Zimbabwe
# continent
# Africa              4.7
# Asia                NaN
# Europe              NaN
# North America       NaN
# Oceania             NaN
# South America       NaN
#
# [6 rows x 193 columns]

# %% [markdown]
# ## [Time Series/Date Functionality](https://pandas.pydata.org/pandas-docs/stable/timeseries.html)

# %% [markdown]
# <!--NAVIGATION-->
# < [Merge Join Concatenate](06_Merge_Join_Concatenate.ipynb) | [Contents](Index.ipynb)
